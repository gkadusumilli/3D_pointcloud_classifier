# %% [markdown]
# <a href="https://colab.research.google.com/github/gkadusumilli/3D_pointcloud_classifier/blob/master/VoxelNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/aayushshah96/VoxelNet.git
# Out:
# Cloning into 'VoxelNet'...
# remote: Enumerating objects: 81, done.
# remote: Total 81 (delta 0), reused 0 (delta 0), pack-reused 81
# Unpacking objects: 100% (81/81), done.

# %%
# %cd /content/VoxelNet
# Out:
# /content/VoxelNet

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext
# building 'utils.box_overlaps' extension
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/utils
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I/usr/include/python3.6m -c ./utils/box_overlaps.c -o build/temp.linux-x86_64-3.6/./utils/box_overlaps.o
# In file included from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1832:0,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from ./utils/box_overlaps.c:498:
# ...

# %%
# %cd /content/VoxelNet/data
# Out:
# /content/VoxelNet/data

# %% [markdown]
# #Velodyne data

# %%
# !wget  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip
# Out:
# --2020-07-15 14:34:34--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.74.76
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.74.76|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28750710812 (27G) [application/zip]
# Saving to: ‘data_object_velodyne.zip’
#
# data_object_velodyn 100%[===================>]  26.78G  29.5MB/s    in 15m 29s
#
# 2020-07-15 14:50:04 (29.5 MB/s) - ‘data_object_velodyne.zip’ saved [28750710812/28750710812]

# %%
# !unzip /content/VoxelNet/data/data_object_velodyne.zip 'training/*' -d /content/VoxelNet/data
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/VoxelNet/data/training/velodyne/005104.bin
#  extracting: /content/VoxelNet/data/training/velodyne/004650.bin
#  extracting: /content/VoxelNet/data/training/velodyne/005744.bin
#  extracting: /content/VoxelNet/data/training/velodyne/004314.bin
#  extracting: /content/VoxelNet/data/training/velodyne/006002.bin
#  extracting: /content/VoxelNet/data/training/velodyne/006909.bin
#  extracting: /content/VoxelNet/data/training/velodyne/004696.bin
#  extracting: /content/VoxelNet/data/training/velodyne/000265.bin
#  extracting: /content/VoxelNet/data/training/velodyne/000142.bin
#  extracting: /content/VoxelNet/data/training/velodyne/003924.bin
#  extracting: /content/VoxelNet/data/training/velodyne/001879.bin
#  extracting: /content/VoxelNet/data/training/velodyne/003490.bin
#  extracting: /content/VoxelNet/data/training/velodyne/003968.bin
#  extracting: /content/VoxelNet/data/training/velodyne/001573.bin
# ...

# %% [markdown]
# #Image

# %%
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip
# Out:
# --2020-07-15 15:05:28--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.47.35
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.47.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12569945557 (12G) [application/zip]
# Saving to: ‘data_object_image_2.zip’
#
# data_object_image_2 100%[===================>]  11.71G  29.6MB/s    in 6m 44s
#
# 2020-07-15 15:12:13 (29.7 MB/s) - ‘data_object_image_2.zip’ saved [12569945557/12569945557]

# %%
# !unzip /content/VoxelNet/data/data_object_image_2.zip 'training/*' -d /content/VoxelNet/data
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/VoxelNet/data/training/image_2/001233.png
#  extracting: /content/VoxelNet/data/training/image_2/005951.png
#  extracting: /content/VoxelNet/data/training/image_2/005044.png
#  extracting: /content/VoxelNet/data/training/image_2/004166.png
#  extracting: /content/VoxelNet/data/training/image_2/004553.png
#  extracting: /content/VoxelNet/data/training/image_2/001976.png
#  extracting: /content/VoxelNet/data/training/image_2/001218.png
#  extracting: /content/VoxelNet/data/training/image_2/000819.png
#  extracting: /content/VoxelNet/data/training/image_2/002842.png
#  extracting: /content/VoxelNet/data/training/image_2/000643.png
#  extracting: /content/VoxelNet/data/training/image_2/003234.png
#  extracting: /content/VoxelNet/data/training/image_2/007239.png
#  extracting: /content/VoxelNet/data/training/image_2/004690.png
#  extracting: /content/VoxelNet/data/training/image_2/003195.png
# ...

# %% [markdown]
# #label-2

# %%
# !wget  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# Out:
# --2020-07-15 15:38:09--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.72.155
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.72.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5601213 (5.3M) [application/zip]
# Saving to: ‘data_object_label_2.zip’
#
# data_object_label_2 100%[===================>]   5.34M  6.67MB/s    in 0.8s
#
# 2020-07-15 15:38:11 (6.67 MB/s) - ‘data_object_label_2.zip’ saved [5601213/5601213]

# %%
# !unzip /content/VoxelNet/data/data_object_label_2.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: training/label_2/000367.txt
#  extracting: training/label_2/006048.txt
#  extracting: training/label_2/005468.txt
#  extracting: training/label_2/007308.txt
#  extracting: training/label_2/001417.txt
#  extracting: training/label_2/006638.txt
#  extracting: training/label_2/002132.txt
#  extracting: training/label_2/002407.txt
#  extracting: training/label_2/007186.txt
#  extracting: training/label_2/004363.txt
#  extracting: training/label_2/005764.txt
#  extracting: training/label_2/003298.txt
#  extracting: training/label_2/002664.txt
#  extracting: training/label_2/002322.txt
#  extracting: training/label_2/005098.txt
#  extracting: training/label_2/007135.txt
#  extracting: training/label_2/001415.txt
#  extracting: training/label_2/000344.txt
#  extracting: training/label_2/005904.txt
#  extracting: training/label_2/007166.txt
#  extracting: training/label_2/000502.txt
#  extracting: training/label_2/006669.txt
# ...

# %%
# !python crop1.py
# Out:
# Traceback (most recent call last):
#   File "crop1.py", line 94, in <module>
#     points = align_img_and_pc(img_dir, pc_dir, calib_dir)
#   File "crop1.py", line 73, in align_img_and_pc
#     r = int(np.round(pts2d_normed[1,i]))
#   File "<__array_function__ internals>", line 4, in round_
#   File "/usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py", line 3126, in _around_dispatcher
#     def _around_dispatcher(a, decimals=None, out=None):
# KeyboardInterrupt

# %%
# %cd /content/VoxelNet
# Out:
# /content/VoxelNet

# %%
# !python train.py
# Out:
# WARNING:tensorflow:From train.py:201: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From train.py:58: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# W0715 16:03:31.449783 140606339688320 module_wrapper.py:139] From train.py:58: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From train.py:61: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0715 16:03:31.450372 140606339688320 module_wrapper.py:139] From train.py:61: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:68: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0715 16:03:31.451050 140606339688320 module_wrapper.py:139] From train.py:68: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
# %cd /content/Voxelnet
# Out:
# /content/Voxelnet

# %%
# %cd /content/Voxelnet/crop_data
# Out:
# /content/Voxelnet/crop_data

# %%
# !wget  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_calib.zip
# Out:
# --2020-07-15 15:39:12--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_calib.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.73.191
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.73.191|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26854811 (26M) [application/zip]
# Saving to: ‘data_object_calib.zip’
#
# data_object_calib.z 100%[===================>]  25.61M  17.1MB/s    in 1.5s
#
# 2020-07-15 15:39:14 (17.1 MB/s) - ‘data_object_calib.zip’ saved [26854811/26854811]

# %%
# !unzip /content/VoxelNet/data/data_object_calib.zip 'training/*' -d /content/VoxelNet/data
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/VoxelNet/data/training/calib/000367.txt
#  extracting: /content/VoxelNet/data/training/calib/006048.txt
#  extracting: /content/VoxelNet/data/training/calib/005468.txt
#  extracting: /content/VoxelNet/data/training/calib/007308.txt
#  extracting: /content/VoxelNet/data/training/calib/001417.txt
#  extracting: /content/VoxelNet/data/training/calib/006638.txt
#  extracting: /content/VoxelNet/data/training/calib/002132.txt
#  extracting: /content/VoxelNet/data/training/calib/002407.txt
#  extracting: /content/VoxelNet/data/training/calib/007186.txt
#  extracting: /content/VoxelNet/data/training/calib/004363.txt
#  extracting: /content/VoxelNet/data/training/calib/005764.txt
#  extracting: /content/VoxelNet/data/training/calib/003298.txt
#  extracting: /content/VoxelNet/data/training/calib/002664.txt
#  extracting: /content/VoxelNet/data/training/calib/002322.txt
# ...

# %%
# %cp -av /content/VoxelNet/data/training /content/VoxelNet/data/validation
# Out:
# Streaming output truncated to the last 5000 lines.
# '/content/VoxelNet/data/training/velodyne/005104.bin' -> '/content/VoxelNet/data/validation/training/velodyne/005104.bin'
# '/content/VoxelNet/data/training/velodyne/004650.bin' -> '/content/VoxelNet/data/validation/training/velodyne/004650.bin'
# '/content/VoxelNet/data/training/velodyne/005744.bin' -> '/content/VoxelNet/data/validation/training/velodyne/005744.bin'
# '/content/VoxelNet/data/training/velodyne/004314.bin' -> '/content/VoxelNet/data/validation/training/velodyne/004314.bin'
# '/content/VoxelNet/data/training/velodyne/006002.bin' -> '/content/VoxelNet/data/validation/training/velodyne/006002.bin'
# '/content/VoxelNet/data/training/velodyne/006909.bin' -> '/content/VoxelNet/data/validation/training/velodyne/006909.bin'
# '/content/VoxelNet/data/training/velodyne/004696.bin' -> '/content/VoxelNet/data/validation/training/velodyne/004696.bin'
# ...

# %%
# %tensorflow_version 1.x
import tensorflow
tensorflow.__version__
# Out:
# TensorFlow 1.x selected.
# '1.15.2'

# %% [markdown]
# # Train_val

# %%
import os

lines_train = [line.rstrip('\n') for line in open('/content/VoxelNet/data/train.txt')]
lines_val = [line.rstrip('\n') for line in open('/content/VoxelNet/data/val.txt')]

#for i in lines_train:
  #  os.remove('/content/VoxelNet/data/training/image_2/'+i+'.png')
  #  os.remove('/content/VoxelNet/data/training/label_2/'+i+'.txt')
  #  os.remove('/content/VoxelNet/data/training/velodyne/'+i+'.bin')

for i in lines_val:
    os.remove('/content/VoxelNet/data/validation/image_2/'+i+'.png')
    os.remove('/content/VoxelNet/data/validation/label_2/'+i+'.txt')
    os.remove('/content/VoxelNet/data/validation/velodyne/'+i+'.bin')

# %%
# !python predict.py \
--strategy="all" \
--batch_size=2 \
--dump_vis="yes" \
--data_root_dir="/content/Voxelnet/crop_data/DATA" \
--dataset_to_test="validation" \
--model_dir="model" \
--model_name="model6" \
--ckpt_name="" \
# Out:
# 2020-07-11 12:44:19.110119: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-11 12:44:21.575130: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-11 12:44:21.578756: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-11 12:44:21.578803: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (d643a243c14a): /proc/driver/nvidia/version does not exist
# 2020-07-11 12:44:21.586841: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-07-11 12:44:21.587157: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3ca4a80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %%
# !zip -r data_voxel.zip /content/VoxelNet/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/VoxelNet/data/validation/calib/001498.txt (deflated 77%)
#   adding: content/VoxelNet/data/validation/calib/006012.txt (deflated 77%)
#   adding: content/VoxelNet/data/validation/calib/005175.txt (deflated 77%)
#   adding: content/VoxelNet/data/validation/calib/007253.txt (deflated 77%)
#   adding: content/VoxelNet/data/validation/calib/006955.txt (deflated 77%)
#   adding: content/VoxelNet/data/validation/calib/006343.txt (deflated 77%)
#   adding: content/VoxelNet/data/validation/calib/005740.txt (deflated 77%)
#   adding: content/VoxelNet/data/validation/calib/001530.txt (deflated 77%)
#   adding: content/VoxelNet/data/validation/calib/007461.txt (deflated 77%)
#   adding: content/VoxelNet/data/validation/calib/001973.txt (deflated 77%)
#   adding: content/VoxelNet/data/validation/calib/000046.txt (deflated 77%)
#   adding: content/VoxelNet/data/validation/calib/003268.txt (deflated 77%)
# ...

# %%
# !zip -r /content/Voxelnet/crop_data/data_lidar.zip /content/Voxelnet/crop_data/DATA/training/

# %%
# !cp -r  /content/Voxelnet/data.zip /content/gdrive/My Drive/
# Out:
# cp: target 'Drive/' is not a directory

# %%
# !ls
# Out:
# build	   data.py  model	  parse_log.py	README.md  utils
# config.py  images   model_helper  predict.py	setup.py
# crop_data  LICENSE  model.py	  __pycache__	train.py

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd /content/drive/My Drive/ImageAI
# Out:
# /content/drive/My Drive/ImageAI

# %%
# !mv "/content/Voxelnet/crop_data/data.zip" "/"
# Out:
# mv: cannot stat '/content/Voxelnet/crop_data/data.zip': No such file or directory

# %%
# !git clone https://github.com/RaviSoji/colab_utils.git
# Out:
# Cloning into 'colab_utils'...
# remote: Enumerating objects: 126, done.
# remote: Total 126 (delta 0), reused 0 (delta 0), pack-reused 126
# Receiving objects: 100% (126/126), 22.95 KiB | 1.35 MiB/s, done.
# Resolving deltas: 100% (78/78), done.

# %%
import colab_utils
drive = colab_utils.get_gdrive()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-04ed9887e5f4> in <module>()
# ----> 1 import colab_utils
#       2 drive = colab_utils.get_gdrive()
#
# ModuleNotFoundError: No module named 'colab_utils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !mv /content/VoxelNet/data /content/drive/My Drive/AI-based-indian-license-plate-detection-master
# Out:
# mv: target 'Drive/AI-based-indian-license-plate-detection-master' is not a directory
